# %% [markdown]
# # Visualizing results from BERT-tiny

# %%
import torch
from transformers import *
import pandas as pd
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def visualize(topk, sentence_num, batch_list, mode='avg'):
    
    for k in batch_list:
        
        batch = str(k)
        sent = str(sentence_num)
        batch_0_x_sent_0 = torch.load('tensor/batch_{}_x_sent_{}.pt'.format(batch, sent)).squeeze(0)
        batch_0_hess_0 = torch.load('tensor/batch_{}_hess_{}.pt'.format(batch, sent)).squeeze(0)
        cause_mask = torch.load('tensor/batch_{}_cause_mask_{}.pt'.format(batch, sent))
        # print(batch_0_x_sent_0)

        ori_sentence = tokenizer.convert_ids_to_tokens(batch_0_x_sent_0)
        print(tokenizer.convert_ids_to_tokens(batch_0_x_sent_0))
        print('\n cause mask: ', [ori_sentence[i] for i in range(len(ori_sentence)) if cause_mask[0][i] != 0], '\n')
        
        temp = dict([i, ori_sentence[i]] for i in range(len(ori_sentence)))

        # print(torch.abs(batch_0_hess_0))
        abs_hess = torch.abs(batch_0_hess_0)
        # no_diag_hess = abs_hess - abs_hess.max() * torch.eye(abs_hess.shape[0], device='cuda:0')

        # abs_hess.split(128)
        # conv = torch.nn.Conv2d(1, 1, (128, 128), padding=0, stride=128).to('cuda:0')(abs_hess.unsqueeze(0).unsqueeze(0))
        avg_hess = torch.nn.AvgPool2d(128, stride=128).to('cuda:0')(abs_hess.unsqueeze(0))[0] - torch.eye(40, device='cuda:0') * 10
        max_hess = torch.nn.MaxPool2d(128, stride=128).to('cuda:0')(abs_hess.unsqueeze(0))[0] - torch.eye(40, device='cuda:0') * 10
        if mode == 'avg':
            values, indices = avg_hess.max(1)
        else:
            values, indices = max_hess.max(1)
        pairs = [[i, int(indices[i]), float(values[i])] for i in range(indices.shape[0]) if float(values[i]) != 0]

        df = pd.DataFrame(pairs)
        df.columns = ['word', 'most relavent', 'score']
        df = df.replace(temp)
        df.sort_values('score', ascending=False, inplace=True)
        print(df.head(topk))

        print("-" * 30 + '\n')

# %% [markdown]
# # Params for visualization

# %%
topk = 10
sentence_num = 10 # select one from 0 to 15
batch_list = [0, 62, 124, 186, 248, 310, 375, 437, 499, 561, 623, 688, 750, 812, 874, 936, 1001, 1063, 1125, 1187, 1249]

# %% [markdown]
# ## Average

# %%
visualize(topk, sentence_num, batch_list, mode='avg')
# Out:
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 18     [SEP]         [SEP]  0.030081
# 24     [SEP]         [SEP]  0.030081
# 0      [CLS]         [SEP]  0.019505
# 8   football         [SEP]  0.012064
# 20      eats         [SEP]  0.010475
# 23      bowl         [SEP]  0.010472
# 6      teams         [SEP]  0.010026
# 16   helmets         [SEP]  0.010012
# 19       dog         [SEP]  0.009394
# 17         .         [SEP]  0.008968
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 19         dog          bowl  0.033713
# 23        bowl           dog  0.033713
# 8     football          bowl  0.027657
# 20        eats          bowl  0.024690
# 13  protection          bowl  0.019320
# 21         out            of  0.017253
# 22          of           out  0.017253
# 0        [CLS]          eats  0.015863
# 14    uniforms          bowl  0.012749
# 16     helmets          bowl  0.012382
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats          bowl  0.132197
# 23      bowl          eats  0.132197
# 8   football          bowl  0.061567
# 19       dog          bowl  0.055735
# 7       play          eats  0.039284
# 4         of          eats  0.038352
# 0      [CLS]          eats  0.028123
# 21       out          eats  0.026303
# 14  uniforms          eats  0.025476
# 16   helmets          eats  0.022011
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 23      bowl           dog  0.157598
# 19       dog          bowl  0.157597
# 20      eats           dog  0.094434
# 21       out          eats  0.089758
# 22        of           out  0.088163
# 8   football          bowl  0.074820
# 0      [CLS]          eats  0.039504
# 14  uniforms          eats  0.033315
# 7       play           dog  0.031982
# 3       boys           dog  0.030847
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 22          of          bowl  0.052347
# 23        bowl            of  0.052347
# 20        eats          bowl  0.047827
# 21         out          bowl  0.042208
# 8     football          bowl  0.034678
# 16     helmets          bowl  0.024684
# 19         dog          bowl  0.022708
# 0        [CLS]          bowl  0.017690
# 14    uniforms          eats  0.014016
# 13  protection          bowl  0.013819
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  0.114774
# 19       dog          eats  0.114774
# 14  uniforms          eats  0.051058
# 23      bowl           dog  0.047285
# 0      [CLS]          eats  0.035117
# 7       play          eats  0.021259
# 16   helmets           dog  0.019271
# 21       out           dog  0.018809
# 22        of      uniforms  0.016474
# 3       boys          eats  0.016075
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  0.123198
# 19       dog          eats  0.123198
# 23      bowl          eats  0.120487
# 14  uniforms          eats  0.092203
# 8   football          bowl  0.082602
# 16   helmets          eats  0.075494
# 21       out          bowl  0.069181
# 22        of           out  0.066666
# 0      [CLS]      uniforms  0.055737
# 3       boys          eats  0.052006
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 7       play          eats  0.133017
# 20      eats          play  0.133017
# 14  uniforms          eats  0.080484
# 23      bowl          eats  0.079154
# 8   football          bowl  0.076381
# 21       out          eats  0.075935
# 3       boys          eats  0.058439
# 19       dog          bowl  0.058334
# 16   helmets          eats  0.049701
# 22        of           out  0.035124
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 19       dog          eats  0.312475
# 20      eats           dog  0.312473
# 14  uniforms          eats  0.191579
# 7       play          eats  0.124256
# 21       out          eats  0.063931
# 8   football          eats  0.063745
# 16   helmets          eats  0.059415
# 22        of           out  0.055355
# 0      [CLS]          eats  0.051562
# 3       boys          eats  0.051036
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 19         dog          eats  0.192426
# 20        eats           dog  0.192426
# 14    uniforms           dog  0.107057
# 23        bowl           dog  0.106290
# 21         out           dog  0.060609
# 8     football          bowl  0.057421
# 13  protection           dog  0.055685
# 3         boys          eats  0.038414
# 22          of          bowl  0.037670
# 7         play          eats  0.036169
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  0.394253
# 19         dog          eats  0.394252
# 14    uniforms           dog  0.210066
# 3         boys          eats  0.084646
# 16     helmets           dog  0.082122
# 23        bowl           dog  0.074918
# 7         play          eats  0.071086
# 0        [CLS]          eats  0.067632
# 13  protection           dog  0.066762
# 12        full           dog  0.066729
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  0.347272
# 19         dog          eats  0.347272
# 14    uniforms          eats  0.231257
# 23        bowl          eats  0.107276
# 16     helmets          eats  0.075652
# 3         boys          eats  0.057558
# 0        [CLS]          eats  0.056161
# 13  protection          eats  0.052957
# 12        full           dog  0.051686
# 7         play          eats  0.049487
# ------------------------------
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  0.485341
# 19       dog          eats  0.485340
# 14  uniforms          eats  0.313330
# 7       play          eats  0.262279
# 23      bowl          eats  0.148391
# 16   helmets          eats  0.145150
# 3       boys          eats  0.129363
# 0      [CLS]          eats  0.127997
# 8   football          eats  0.125383
# 21       out          eats  0.054439
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 7         play          eats  0.199473
# 20        eats          play  0.199472
# 19         dog          eats  0.195065
# 14    uniforms          eats  0.189789
# 0        [CLS]          eats  0.113787
# 16     helmets          eats  0.080289
# 8     football          eats  0.072722
# 23        bowl           dog  0.066112
# 21         out          eats  0.061629
# 13  protection          eats  0.026839
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  0.431178
# 19         dog          eats  0.431177
# 23        bowl           dog  0.223339
# 14    uniforms           dog  0.187364
# 16     helmets           dog  0.179506
# 8     football          bowl  0.170813
# 7         play          eats  0.127165
# 0        [CLS]           dog  0.086852
# 21         out          bowl  0.065184
# 13  protection           dog  0.046742
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 19       dog          eats  0.467875
# 20      eats           dog  0.467875
# 14  uniforms          eats  0.190728
# 0      [CLS]          eats  0.171281
# 7       play          eats  0.160348
# 23      bowl           dog  0.154421
# 3       boys          eats  0.131714
# 16   helmets          eats  0.119204
# 8   football          eats  0.082197
# 21       out          eats  0.069073
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 19         dog          eats  0.212025
# 20        eats           dog  0.212025
# 23        bowl          eats  0.107015
# 14    uniforms           dog  0.082127
# 21         out           dog  0.040087
# 8     football          bowl  0.036642
# 16     helmets          eats  0.036418
# 0        [CLS]           dog  0.035808
# 22          of           dog  0.027171
# 13  protection           dog  0.027037
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  0.375805
# 19       dog          eats  0.375805
# 23      bowl           dog  0.353421
# 7       play          eats  0.212914
# 8   football          bowl  0.149947
# 3       boys          eats  0.146014
# 14  uniforms          eats  0.120777
# 16   helmets          eats  0.085539
# 21       out          bowl  0.077335
# 12      full          bowl  0.058209
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 7         play          eats  0.575284
# 20        eats          play  0.575283
# 19         dog          eats  0.415470
# 23        bowl          eats  0.268602
# 8     football          eats  0.163911
# 14    uniforms          eats  0.146103
# 0        [CLS]          eats  0.127617
# 16     helmets          eats  0.113980
# 13  protection          eats  0.109070
# 3         boys          eats  0.084510
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 19         dog          eats  0.351890
# 20        eats           dog  0.351888
# 8     football          bowl  0.320690
# 23        bowl      football  0.320690
# 14    uniforms           dog  0.189341
# 7         play          eats  0.141662
# 0        [CLS]          eats  0.095930
# 16     helmets           dog  0.077488
# 21         out          bowl  0.067145
# 13  protection          eats  0.065647
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  0.462276
# 19       dog          eats  0.462276
# 23      bowl          eats  0.256132
# 7       play          eats  0.255195
# 14  uniforms           dog  0.225631
# 8   football          bowl  0.166456
# 3       boys          eats  0.120097
# 16   helmets          eats  0.094456
# 21       out          bowl  0.090531
# 0      [CLS]          eats  0.086251
# ------------------------------

# %% [markdown]
# ## Max

# %%
visualize(topk, sentence_num, batch_list, mode='max')
# Out:
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 24     [SEP]         [SEP]  0.604129
# 18     [SEP]         [SEP]  0.604129
# 0      [CLS]         [SEP]  0.594729
# 17         .         [CLS]  0.275844
# 8   football         [SEP]  0.233400
# 19       dog         [SEP]  0.167147
# 16   helmets         [SEP]  0.165270
# 20      eats         [CLS]  0.146375
# 23      bowl         [SEP]  0.145649
# 6      teams         [SEP]  0.135518
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 23        bowl           dog  1.307575
# 19         dog          bowl  1.307575
# 8     football          bowl  0.596445
# 13  protection          bowl  0.424215
# 20        eats          bowl  0.367880
# 0        [CLS]          eats  0.325403
# 16     helmets          bowl  0.322234
# 14    uniforms          bowl  0.278821
# 3         boys          bowl  0.221439
# 18       [SEP]          bowl  0.207440
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats          bowl  2.866120
# 23      bowl          eats  2.866120
# 19       dog          bowl  2.356844
# 8   football          bowl  1.372195
# 7       play          eats  0.894991
# 4         of          eats  0.714680
# 3       boys          eats  0.389425
# 11   wearing          eats  0.380552
# 0      [CLS]           dog  0.375146
# 21       out          bowl  0.309029
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 23        bowl           dog  5.513483
# 19         dog          bowl  5.513483
# 20        eats           dog  2.076277
# 8     football          bowl  1.546284
# 21         out           dog  1.088097
# 14    uniforms          eats  0.897664
# 0        [CLS]           dog  0.816394
# 22          of           out  0.808343
# 7         play          eats  0.388007
# 13  protection           dog  0.380600
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 23        bowl          eats  0.669946
# 20        eats          bowl  0.669946
# 22          of          bowl  0.582358
# 8     football          bowl  0.482987
# 21         out          bowl  0.458266
# 16     helmets          bowl  0.348561
# 0        [CLS]          bowl  0.295051
# 19         dog          bowl  0.266727
# 13  protection          bowl  0.167560
# 14    uniforms          bowl  0.165410
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  1.401723
# 19         dog          eats  1.401723
# 23        bowl           dog  0.864861
# 14    uniforms          eats  0.663872
# 16     helmets           dog  0.467713
# 0        [CLS]           dog  0.393882
# 22          of      uniforms  0.371681
# 7         play          eats  0.320647
# 3         boys          eats  0.269933
# 13  protection           dog  0.225570
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  2.498724
# 19         dog          eats  2.498724
# 23        bowl           dog  2.044358
# 16     helmets          bowl  1.653167
# 14    uniforms           dog  1.277053
# 21         out          eats  0.892934
# 3         boys          eats  0.890807
# 7         play          eats  0.841963
# 8     football          bowl  0.736481
# 13  protection          eats  0.578796
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 7       play          eats  1.336508
# 20      eats          play  1.336508
# 23      bowl      football  1.063040
# 8   football          bowl  1.063040
# 19       dog          bowl  1.017965
# 14  uniforms          eats  0.831801
# 21       out          eats  0.827419
# 3       boys          eats  0.626493
# 16   helmets          bowl  0.491536
# 5   opposing          bowl  0.300830
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  7.345563
# 19       dog          eats  7.345563
# 14  uniforms          eats  3.180580
# 7       play          eats  1.133356
# 21       out          eats  1.028649
# 23      bowl           dog  0.925172
# 16   helmets          eats  0.840285
# 0      [CLS]          eats  0.673664
# 3       boys          eats  0.616705
# 22        of           out  0.563040
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 19         dog           dog  5.521678
# 20        eats           dog  3.495053
# 14    uniforms           dog  2.175423
# 23        bowl           dog  1.960705
# 13  protection           dog  1.272459
# 21         out           dog  1.033099
# 22          of           dog  0.955817
# 0        [CLS]           dog  0.767053
# 16     helmets           dog  0.723141
# 7         play           dog  0.700140
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent      score
# 19         dog           dog  16.586145
# 20        eats           dog   5.050025
# 14    uniforms           dog   4.479696
# 16     helmets           dog   1.438302
# 13  protection           dog   1.075823
# 0        [CLS]           dog   0.921619
# 23        bowl          eats   0.831957
# 3         boys          eats   0.742913
# 22          of           dog   0.660843
# 7         play          eats   0.660124
# ------------------------------
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  4.188957
# 19         dog          eats  4.188957
# 14    uniforms          eats  2.664770
# 12        full          eats  1.026166
# 23        bowl          eats  1.023168
# 16     helmets          eats  0.935852
# 13  protection          eats  0.837115
# 21         out          eats  0.782858
# 3         boys          eats  0.638935
# 0        [CLS]          eats  0.618322
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  6.895405
# 19       dog          eats  6.895405
# 14  uniforms          eats  3.468834
# 7       play          eats  2.485372
# 16   helmets          eats  2.144027
# 23      bowl          eats  1.631394
# 3       boys          eats  1.300270
# 8   football          eats  1.197526
# 0      [CLS]          eats  1.166785
# 21       out          eats  0.645676
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats      uniforms  2.940966
# 14  uniforms          eats  2.940966
# 19       dog          eats  2.295884
# 7       play          eats  2.169472
# 0      [CLS]          eats  1.142949
# 21       out          eats  0.899373
# 16   helmets          eats  0.860680
# 8   football          eats  0.841234
# 23      bowl           dog  0.764385
# 22        of          eats  0.397468
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 19         dog           dog  8.330204
# 20        eats           dog  4.976545
# 23        bowl           dog  2.722865
# 14    uniforms           dog  2.296050
# 16     helmets           dog  1.984333
# 8     football          bowl  1.982319
# 0        [CLS]           dog  1.544008
# 7         play           dog  1.453698
# 21         out           dog  0.781663
# 13  protection           dog  0.602269
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  4.692099
# 19       dog          eats  4.692099
# 23      bowl           dog  2.292909
# 3       boys          eats  1.724043
# 7       play          eats  1.675911
# 14  uniforms          eats  1.494556
# 8   football           dog  1.199082
# 0      [CLS]          eats  1.130328
# 16   helmets           dog  0.887936
# 21       out           dog  0.636104
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  2.091572
# 19         dog          eats  2.091572
# 14    uniforms          eats  1.303912
# 23        bowl           dog  1.176857
# 16     helmets          eats  0.513337
# 8     football          bowl  0.509458
# 0        [CLS]          eats  0.480575
# 21         out           dog  0.434892
# 13  protection          eats  0.371136
# 3         boys          eats  0.289014
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 23      bowl           dog  4.076857
# 19       dog          bowl  4.076857
# 20      eats           dog  3.781781
# 7       play          eats  2.036041
# 8   football          bowl  1.800797
# 3       boys          eats  1.792641
# 14  uniforms          eats  1.336087
# 21       out          bowl  0.826778
# 16   helmets          eats  0.733574
# 22        of           dog  0.715378
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats          play  6.469368
# 7         play          eats  6.469368
# 19         dog          eats  4.590037
# 23        bowl          eats  2.448411
# 14    uniforms          eats  1.408007
# 8     football          eats  1.387635
# 0        [CLS]          eats  1.269605
# 13  protection          eats  1.053717
# 16     helmets          eats  1.031448
# 3         boys          eats  0.941209
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 23        bowl      football  4.178994
# 8     football          bowl  4.178994
# 20        eats           dog  3.988351
# 19         dog          eats  3.988351
# 14    uniforms          eats  2.123927
# 7         play          eats  1.560965
# 0        [CLS]          eats  1.091478
# 16     helmets           dog  1.039615
# 13  protection          eats  0.760659
# 21         out          bowl  0.683982
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  4.678293
# 19       dog          eats  4.678293
# 23      bowl           dog  2.554242
# 7       play          eats  2.377668
# 8   football          bowl  2.292961
# 14  uniforms          eats  2.069893
# 3       boys          eats  1.471442
# 16   helmets          eats  1.063383
# 21       out          bowl  0.914993
# 0      [CLS]          eats  0.848894
# ------------------------------
