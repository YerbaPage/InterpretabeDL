# %% [markdown]
# # Visualizing results from BERT-tiny

# %%
import torch
from transformers import *
import pandas as pd
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def visualize(topk, sentence_num, batch_list, mode='avg'):
    
    for k in batch_list:
        
        batch = str(k)
        sent = str(sentence_num)
        batch_0_x_sent_0 = torch.load('tensor/batch_{}_x_sent_{}.pt'.format(batch, sent)).squeeze(0)
        batch_0_hess_0 = torch.load('tensor/batch_{}_hess_{}.pt'.format(batch, sent)).squeeze(0)
        cause_mask = torch.load('tensor/batch_{}_cause_mask_{}.pt'.format(batch, sent))
        # print(batch_0_x_sent_0)

        ori_sentence = tokenizer.convert_ids_to_tokens(batch_0_x_sent_0)
        print(tokenizer.convert_ids_to_tokens(batch_0_x_sent_0))
        print('\n cause mask: ', [ori_sentence[i] for i in range(len(ori_sentence)) if cause_mask[0][i] != 0], '\n')
        
        temp = dict([i, ori_sentence[i]] for i in range(len(ori_sentence)))

        # print(torch.abs(batch_0_hess_0))
        abs_hess = torch.abs(batch_0_hess_0)
        # no_diag_hess = abs_hess - abs_hess.max() * torch.eye(abs_hess.shape[0], device='cuda:0')

        # abs_hess.split(128)
        # conv = torch.nn.Conv2d(1, 1, (128, 128), padding=0, stride=128).to('cuda:0')(abs_hess.unsqueeze(0).unsqueeze(0))
        avg_hess = torch.nn.AvgPool2d(128, stride=128).to('cuda:0')(abs_hess.unsqueeze(0))[0] - torch.eye(40, device='cuda:0') * 10
        max_hess = torch.nn.MaxPool2d(128, stride=128).to('cuda:0')(abs_hess.unsqueeze(0))[0] - torch.eye(40, device='cuda:0') * 10
        if mode == 'avg':
            values, indices = torch.topk(avg_hess.view(-1), 2*topk)
        else:
            values, indices = torch.topk(max_hess.view(-1), 2*topk)

        row = indices // 40
        col = indices % 40
        # pairs = [[i, int(indices[i]), float(values[i])] for i in range(indices.shape[0]) if float(values[i]) != 0]
        pairs = [[int(row[i]), int(col[i]), float(values[i])] for i in range(indices.shape[0]) if float(values[i]) != 0]
        df = pd.DataFrame(pairs)
        df.columns = ['word', 'most relavent', 'score']
        df = df.replace(temp)
        df.sort_values('score', ascending=False, inplace=True)
        print(df[df.index%2==0].head(topk))

        print("-" * 30 + '\n')

# %% [markdown]
# # Params for visualization

# %%
topk = 10
sentence_num = 9 # select one from 0 to 15
# batch_list = [0, 62, 124, 186, 248, 310, 375, 437, 499, 561, 623, 688, 750, 812, 874, 936, 1001, 1063, 1125, 1187, 1249]
batch_list = [0, 310, 623, 936, 1249]

# %% [markdown]
# ## Average

# %%
visualize(topk, sentence_num, batch_list, mode='avg')
# Out:
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'boys', 'play', 'football', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'opposing', 'teams', 'play', 'boys', 'play', 'football']
#
#         word most relavent     score
# 0      [SEP]         [SEP]  0.044089
# 2      [CLS]         [SEP]  0.025706
# 4      [CLS]         [SEP]  0.024833
# 6      [SEP]             .  0.014351
# 8   football         [SEP]  0.014056
# 10         .         [SEP]  0.013824
# 12     [SEP]      football  0.011118
# 14     [SEP]      football  0.010987
# 16  football         [SEP]  0.010924
# 18     [SEP]       helmets  0.010910
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'boys', 'play', 'football', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'opposing', 'teams', 'play', 'boys', 'play', 'football']
#
#         word most relavent     score
# 0    helmets      football  0.104266
# 2   football      football  0.101465
# 4   football      uniforms  0.090533
# 6   football       helmets  0.085855
# 8    helmets      uniforms  0.063052
# 10  uniforms         [CLS]  0.048258
# 12  football          play  0.046607
# 14   helmets    protection  0.044967
# 16  football         [SEP]  0.042081
# 18      play       helmets  0.038749
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'boys', 'play', 'football', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'opposing', 'teams', 'play', 'boys', 'play', 'football']
#
#           word most relavent     score
# 0     football       helmets  0.091093
# 2     football      uniforms  0.084339
# 4         full      football  0.077175
# 6      helmets      football  0.073038
# 8      helmets      uniforms  0.070910
# 10    football    protection  0.067877
# 12  protection       helmets  0.054378
# 14        full       helmets  0.049429
# 16    uniforms          full  0.044592
# 18    football      football  0.043941
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'boys', 'play', 'football', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'opposing', 'teams', 'play', 'boys', 'play', 'football']
#
#         word most relavent     score
# 0   football      football  0.072671
# 2   football          full  0.066686
# 4   football      uniforms  0.061876
# 6       full      uniforms  0.055927
# 8   uniforms       helmets  0.052908
# 10     [CLS]      uniforms  0.047154
# 12  uniforms    protection  0.036258
# 14  football       helmets  0.033352
# 16  football         [CLS]  0.033334
# 18  uniforms      football  0.030910
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'boys', 'play', 'football', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'opposing', 'teams', 'play', 'boys', 'play', 'football']
#
#           word most relavent     score
# 0     uniforms      football  0.074649
# 2     football      football  0.066511
# 4     football    protection  0.063651
# 6     uniforms       helmets  0.059437
# 8   protection      uniforms  0.058242
# 10     helmets      football  0.045852
# 12    football      uniforms  0.037014
# 14       [SEP]      football  0.034081
# 16  protection       helmets  0.032194
# 18    football          full  0.032097
# ------------------------------

# %% [markdown]
# ## Max

# %%
visualize(topk, sentence_num, batch_list, mode='max')
# Out:
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 24     [SEP]         [SEP]  0.604129
# 18     [SEP]         [SEP]  0.604129
# 0      [CLS]         [SEP]  0.594729
# 17         .         [CLS]  0.275844
# 8   football         [SEP]  0.233400
# 19       dog         [SEP]  0.167147
# 16   helmets         [SEP]  0.165270
# 20      eats         [CLS]  0.146375
# 23      bowl         [SEP]  0.145649
# 6      teams         [SEP]  0.135518
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 23        bowl           dog  1.307575
# 19         dog          bowl  1.307575
# 8     football          bowl  0.596445
# 13  protection          bowl  0.424215
# 20        eats          bowl  0.367880
# 0        [CLS]          eats  0.325403
# 16     helmets          bowl  0.322234
# 14    uniforms          bowl  0.278821
# 3         boys          bowl  0.221439
# 18       [SEP]          bowl  0.207440
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats          bowl  2.866120
# 23      bowl          eats  2.866120
# 19       dog          bowl  2.356844
# 8   football          bowl  1.372195
# 7       play          eats  0.894991
# 4         of          eats  0.714680
# 3       boys          eats  0.389425
# 11   wearing          eats  0.380552
# 0      [CLS]           dog  0.375146
# 21       out          bowl  0.309029
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 23        bowl           dog  5.513483
# 19         dog          bowl  5.513483
# 20        eats           dog  2.076277
# 8     football          bowl  1.546284
# 21         out           dog  1.088097
# 14    uniforms          eats  0.897664
# 0        [CLS]           dog  0.816394
# 22          of           out  0.808343
# 7         play          eats  0.388007
# 13  protection           dog  0.380600
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 23        bowl          eats  0.669946
# 20        eats          bowl  0.669946
# 22          of          bowl  0.582358
# 8     football          bowl  0.482987
# 21         out          bowl  0.458266
# 16     helmets          bowl  0.348561
# 0        [CLS]          bowl  0.295051
# 19         dog          bowl  0.266727
# 13  protection          bowl  0.167560
# 14    uniforms          bowl  0.165410
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  1.401723
# 19         dog          eats  1.401723
# 23        bowl           dog  0.864861
# 14    uniforms          eats  0.663872
# 16     helmets           dog  0.467713
# 0        [CLS]           dog  0.393882
# 22          of      uniforms  0.371681
# 7         play          eats  0.320647
# 3         boys          eats  0.269933
# 13  protection           dog  0.225570
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  2.498724
# 19         dog          eats  2.498724
# 23        bowl           dog  2.044358
# 16     helmets          bowl  1.653167
# 14    uniforms           dog  1.277053
# 21         out          eats  0.892934
# 3         boys          eats  0.890807
# 7         play          eats  0.841963
# 8     football          bowl  0.736481
# 13  protection          eats  0.578796
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 7       play          eats  1.336508
# 20      eats          play  1.336508
# 23      bowl      football  1.063040
# 8   football          bowl  1.063040
# 19       dog          bowl  1.017965
# 14  uniforms          eats  0.831801
# 21       out          eats  0.827419
# 3       boys          eats  0.626493
# 16   helmets          bowl  0.491536
# 5   opposing          bowl  0.300830
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  7.345563
# 19       dog          eats  7.345563
# 14  uniforms          eats  3.180580
# 7       play          eats  1.133356
# 21       out          eats  1.028649
# 23      bowl           dog  0.925172
# 16   helmets          eats  0.840285
# 0      [CLS]          eats  0.673664
# 3       boys          eats  0.616705
# 22        of           out  0.563040
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 19         dog           dog  5.521678
# 20        eats           dog  3.495053
# 14    uniforms           dog  2.175423
# 23        bowl           dog  1.960705
# 13  protection           dog  1.272459
# 21         out           dog  1.033099
# 22          of           dog  0.955817
# 0        [CLS]           dog  0.767053
# 16     helmets           dog  0.723141
# 7         play           dog  0.700140
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent      score
# 19         dog           dog  16.586145
# 20        eats           dog   5.050025
# 14    uniforms           dog   4.479696
# 16     helmets           dog   1.438302
# 13  protection           dog   1.075823
# 0        [CLS]           dog   0.921619
# 23        bowl          eats   0.831957
# 3         boys          eats   0.742913
# 22          of           dog   0.660843
# 7         play          eats   0.660124
# ------------------------------
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  4.188957
# 19         dog          eats  4.188957
# 14    uniforms          eats  2.664770
# 12        full          eats  1.026166
# 23        bowl          eats  1.023168
# 16     helmets          eats  0.935852
# 13  protection          eats  0.837115
# 21         out          eats  0.782858
# 3         boys          eats  0.638935
# 0        [CLS]          eats  0.618322
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  6.895405
# 19       dog          eats  6.895405
# 14  uniforms          eats  3.468834
# 7       play          eats  2.485372
# 16   helmets          eats  2.144027
# 23      bowl          eats  1.631394
# 3       boys          eats  1.300270
# 8   football          eats  1.197526
# 0      [CLS]          eats  1.166785
# 21       out          eats  0.645676
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats      uniforms  2.940966
# 14  uniforms          eats  2.940966
# 19       dog          eats  2.295884
# 7       play          eats  2.169472
# 0      [CLS]          eats  1.142949
# 21       out          eats  0.899373
# 16   helmets          eats  0.860680
# 8   football          eats  0.841234
# 23      bowl           dog  0.764385
# 22        of          eats  0.397468
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 19         dog           dog  8.330204
# 20        eats           dog  4.976545
# 23        bowl           dog  2.722865
# 14    uniforms           dog  2.296050
# 16     helmets           dog  1.984333
# 8     football          bowl  1.982319
# 0        [CLS]           dog  1.544008
# 7         play           dog  1.453698
# 21         out           dog  0.781663
# 13  protection           dog  0.602269
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  4.692099
# 19       dog          eats  4.692099
# 23      bowl           dog  2.292909
# 3       boys          eats  1.724043
# 7       play          eats  1.675911
# 14  uniforms          eats  1.494556
# 8   football           dog  1.199082
# 0      [CLS]          eats  1.130328
# 16   helmets           dog  0.887936
# 21       out           dog  0.636104
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats           dog  2.091572
# 19         dog          eats  2.091572
# 14    uniforms          eats  1.303912
# 23        bowl           dog  1.176857
# 16     helmets          eats  0.513337
# 8     football          bowl  0.509458
# 0        [CLS]          eats  0.480575
# 21         out           dog  0.434892
# 13  protection          eats  0.371136
# 3         boys          eats  0.289014
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 23      bowl           dog  4.076857
# 19       dog          bowl  4.076857
# 20      eats           dog  3.781781
# 7       play          eats  2.036041
# 8   football          bowl  1.800797
# 3       boys          eats  1.792641
# 14  uniforms          eats  1.336087
# 21       out          bowl  0.826778
# 16   helmets          eats  0.733574
# 22        of           dog  0.715378
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 20        eats          play  6.469368
# 7         play          eats  6.469368
# 19         dog          eats  4.590037
# 23        bowl          eats  2.448411
# 14    uniforms          eats  1.408007
# 8     football          eats  1.387635
# 0        [CLS]          eats  1.269605
# 13  protection          eats  1.053717
# 16     helmets          eats  1.031448
# 3         boys          eats  0.941209
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#           word most relavent     score
# 23        bowl      football  4.178994
# 8     football          bowl  4.178994
# 20        eats           dog  3.988351
# 19         dog          eats  3.988351
# 14    uniforms          eats  2.123927
# 7         play          eats  1.560965
# 0        [CLS]          eats  1.091478
# 16     helmets           dog  1.039615
# 13  protection          eats  0.760659
# 21         out          bowl  0.683982
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'boys', 'of', 'opposing', 'teams', 'play', 'football', ',', 'while', 'wearing', 'full', 'protection', 'uniforms', 'and', 'helmets', '.', '[SEP]', 'dog', 'eats', 'out', 'of', 'bowl', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#
#  cause mask:  ['boys', 'dog']
#
#         word most relavent     score
# 20      eats           dog  4.678293
# 19       dog          eats  4.678293
# 23      bowl           dog  2.554242
# 7       play          eats  2.377668
# 8   football          bowl  2.292961
# 14  uniforms          eats  2.069893
# 3       boys          eats  1.471442
# 16   helmets          eats  1.063383
# 21       out          bowl  0.914993
# 0      [CLS]          eats  0.848894
# ------------------------------
