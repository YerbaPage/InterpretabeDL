# %%
import json
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/e-snli/esnli_train.csv')

# %%
df['Sentence1']
# Out:
# 0         A person on a horse jumps over a broken down a...
# 1         A person on a horse jumps over a broken down a...
# 2         A person on a horse jumps over a broken down a...
# 3                     Children smiling and waving at camera
# 4                     Children smiling and waving at camera
#                                 ...
# 259994    Man in black pants and vest balances between t...
# 259995    Man in black pants and vest balances between t...
# 259996    Man in black pants and vest balances between t...
# 259997    Man in black pants and vest balances between t...
# 259998    Man in black pants and vest balances between t...
# Name: Sentence1, Length: 259999, dtype: object

# %%
test = df['Sentence1'][0]

# %%
len(test.split(' '))
# Out:
# 11

# %%
length = [len(x.split(' ')) for x in df['Sentence1']]
lengths = np.array(length)
df['len'] = length

df.head(20
       )
# Out:
#                  pairID     gold_label  \
# 0   3416050480.jpg#4r1n        neutral
# 1   3416050480.jpg#4r1c  contradiction
# 2   3416050480.jpg#4r1e     entailment
# 3   2267923837.jpg#2r1n        neutral
# 4   2267923837.jpg#2r1e     entailment
# 5   2267923837.jpg#2r1c  contradiction
# 6   3691670743.jpg#0r1c  contradiction
# 7   3691670743.jpg#0r1e     entailment
# 8   3691670743.jpg#0r1n        neutral
# 9   4804607632.jpg#0r1n        neutral
# 10  4804607632.jpg#0r1c  contradiction
# 11  4804607632.jpg#0r1e        neutral
# 12  4705552913.jpg#4r1n        neutral
# 13  4705552913.jpg#4r1c  contradiction
# 14  4705552913.jpg#4r1e     entailment
# 15  4804607632.jpg#2r1n        neutral
# 16  4804607632.jpg#2r1c  contradiction
# 17  4804607632.jpg#2r1e     entailment
# 18  4804607632.jpg#3r1e     entailment
# 19  4804607632.jpg#3r1c  contradiction
#
#                                             Sentence1  \
# 0   A person on a horse jumps over a broken down a...
# ...

# %%
sns.distplot(df['len'])
# Out:
# /home/shiyuling/.conda/envs/interp/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='len', ylabel='Density'>
