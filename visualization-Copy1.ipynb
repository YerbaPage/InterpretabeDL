# %% [markdown]
# # Visualizing results from BERT-tiny

# %%
import torch
from transformers import *
import pandas as pd
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %% [markdown]
# # Params for visualization

# %%
topk = 10 # k
sentence_num = 0 # select one from 0 to 15
batch_list = [0, 62, 124, 186, 248, 310, 375, 437, 499, 561, 623, 688, 750, 812, 874, 936, 1001, 1063, 1125, 1187, 1249]

# %% [markdown]
# ## Average

# %%
for k in batch_list:
    batch = str(k)
    sent = str(sentence_num)
    batch_0_x_sent_0 = torch.load('tensor/batch_{}_x_sent_{}.pt'.format(batch, sent)).squeeze(0)
    batch_0_hess_0 = torch.load('tensor/batch_{}_hess_{}.pt'.format(batch, sent)).squeeze(0)
    # print(batch_0_x_sent_0)

    ori_sentence = tokenizer.convert_ids_to_tokens(batch_0_x_sent_0)
    print(tokenizer.convert_ids_to_tokens(batch_0_x_sent_0))
    temp = dict([i, ori_sentence[i]] for i in range(len(ori_sentence)))

    # print(torch.abs(batch_0_hess_0))
    abs_hess = torch.abs(batch_0_hess_0)
    # no_diag_hess = abs_hess - abs_hess.max() * torch.eye(abs_hess.shape[0], device='cuda:0')

    # abs_hess.split(128)
    # conv = torch.nn.Conv2d(1, 1, (128, 128), padding=0, stride=128).to('cuda:0')(abs_hess.unsqueeze(0).unsqueeze(0))
    avg_hess = torch.nn.AvgPool2d(128, stride=128).to('cuda:0')(abs_hess.unsqueeze(0))[0] - torch.eye(40, device='cuda:0') * 10
    max_hess = torch.nn.MaxPool2d(128, stride=128).to('cuda:0')(abs_hess.unsqueeze(0))[0] - torch.eye(40, device='cuda:0') * 10

    values, indices = avg_hess.max(1)
    pairs = [[i, int(indices[i]), float(values[i])] for i in range(indices.shape[0]) if float(values[i]) != 0]

    df = pd.DataFrame(pairs)
    df.columns = ['word', 'most relavent', 'score']
    df = df.replace(temp)
    df.sort_values('score', ascending=False, inplace=True)
    print(df.head(topk))

    print("-" * 30 + '\n')
# Out:
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 11     [SEP]         [SEP]  0.027162
# 27     [SEP]         [SEP]  0.027162
# 0      [CLS]         [SEP]  0.017655
# 2      women         [CLS]  0.010214
# 21  packages         [SEP]  0.008625
# 25     lunch         [SEP]  0.008502
# 24    eating         [SEP]  0.008386
# 14       are         [SEP]  0.007699
# 9   packages         [SEP]  0.007692
# 26         .         [SEP]  0.007598
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating            to  0.020484
# 19        to        eating  0.020484
# 20        go            to  0.020136
# 25     lunch        eating  0.016241
# 21  packages            to  0.013002
# 9   packages      packages  0.010771
# 27     [SEP]        eating  0.010680
# 8         go            go  0.010606
# 22     after            to  0.010037
# 0      [CLS]        eating  0.009877
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch        eating  0.018728
# 24    eating         lunch  0.018728
# 22     after        eating  0.018388
# 19        to         after  0.016751
# 0      [CLS]        eating  0.016436
# 20        go            to  0.014293
# 21  packages        eating  0.010448
# 17     while        eating  0.007403
# 23      just        eating  0.006583
# 9   packages      packages  0.005990
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 22     after        eating  0.070202
# 24    eating         after  0.070201
# 25     lunch        eating  0.066209
# 0      [CLS]        eating  0.047046
# 19        to        eating  0.041237
# 23      just        eating  0.020747
# 16   goodbye        eating  0.019164
# 20        go        eating  0.017575
# 27     [SEP]        eating  0.015066
# 21  packages        eating  0.014894
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating         after  0.140180
# 22     after        eating  0.140179
# 25     lunch        eating  0.078374
# 0      [CLS]        eating  0.067944
# 19        to        eating  0.061042
# 27     [SEP]        eating  0.036382
# 23      just        eating  0.029860
# 18   holding        eating  0.019408
# 21  packages        eating  0.018573
# 2      women        eating  0.013542
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#        word most relavent     score
# 25    lunch        eating  0.076846
# 24   eating         lunch  0.076846
# 22    after        eating  0.074564
# 23     just         after  0.046931
# 0     [CLS]        eating  0.036415
# 13  sisters         [CLS]  0.015747
# 27    [SEP]        eating  0.013716
# 2     women        eating  0.013163
# 20       go        eating  0.012231
# 19       to        eating  0.009980
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch        eating  0.159062
# 24    eating         lunch  0.159062
# 22     after         lunch  0.135717
# 0      [CLS]        eating  0.052447
# 13   sisters        eating  0.049181
# 2      women        eating  0.027321
# 20        go        eating  0.025313
# 19        to         lunch  0.021318
# 23      just        eating  0.018140
# 21  packages        eating  0.016101
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch        eating  0.157232
# 24    eating         lunch  0.157232
# 23      just         after  0.067761
# 22     after          just  0.067761
# 13   sisters        eating  0.052915
# 0      [CLS]        eating  0.046567
# 20        go         after  0.040591
# 9   packages      packages  0.035676
# 21  packages      packages  0.035676
# 8         go            go  0.034921
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch        eating  0.175047
# 24    eating         lunch  0.175047
# 22     after        eating  0.081584
# 13   sisters        eating  0.070795
# 0      [CLS]        eating  0.052399
# 23      just        eating  0.048646
# 7         to        eating  0.033917
# 19        to         lunch  0.033770
# 21  packages        eating  0.026179
# 5      while        eating  0.021572
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating         lunch  0.130083
# 25     lunch        eating  0.130083
# 22     after        eating  0.116088
# 13   sisters        eating  0.044907
# 0      [CLS]        eating  0.037083
# 23      just        eating  0.037066
# 27     [SEP]        eating  0.029000
# 21  packages        eating  0.027726
# 7         to        eating  0.019701
# 16   goodbye        eating  0.019584
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating         lunch  0.113413
# 25     lunch        eating  0.113413
# 22     after        eating  0.103965
# 13   sisters        eating  0.030811
# 23      just         after  0.029863
# 9   packages        eating  0.029305
# 0      [CLS]        eating  0.027549
# 21  packages        eating  0.023568
# 5      while        eating  0.018864
# 7         to        eating  0.018759
# ------------------------------
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating         after  0.226389
# 22     after        eating  0.226389
# 25     lunch        eating  0.177628
# 13   sisters        eating  0.094673
# 21  packages        eating  0.054662
# 0      [CLS]        eating  0.053909
# 23      just        eating  0.048295
# 27     [SEP]        eating  0.041048
# 16   goodbye        eating  0.026809
# 19        to        eating  0.020754
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 25      lunch        eating  0.205042
# 24     eating         lunch  0.205042
# 13    sisters        eating  0.158693
# 22      after        eating  0.131334
# 21   packages        eating  0.047775
# 0       [CLS]        eating  0.041527
# 4   embracing        eating  0.029789
# 15    hugging        eating  0.026678
# 16    goodbye        eating  0.026650
# 9    packages        eating  0.026029
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating       sisters  0.102308
# 13   sisters        eating  0.102307
# 25     lunch        eating  0.095576
# 0      [CLS]        eating  0.066856
# 22     after        eating  0.058076
# 21  packages        eating  0.042421
# 23      just        eating  0.040978
# 16   goodbye        eating  0.024236
# 19        to         lunch  0.022959
# 20        go        eating  0.021380
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating         lunch  0.117501
# 25     lunch        eating  0.117501
# 22     after        eating  0.083453
# 13   sisters        eating  0.073550
# 21  packages        eating  0.058629
# 0      [CLS]        eating  0.035799
# 23      just        eating  0.035213
# 16   goodbye        eating  0.031014
# 17     while        eating  0.025781
# 27     [SEP]        eating  0.022952
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch        eating  0.176241
# 24    eating         lunch  0.176241
# 22     after        eating  0.141580
# 13   sisters        eating  0.117123
# 21  packages        eating  0.059264
# 0      [CLS]        eating  0.041446
# 16   goodbye        eating  0.038418
# 23      just        eating  0.034861
# 15   hugging        eating  0.025834
# 18   holding        eating  0.020603
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating         lunch  0.497450
# 25     lunch        eating  0.497448
# 22     after         lunch  0.396018
# 13   sisters        eating  0.146986
# 21  packages        eating  0.118322
# 23      just         lunch  0.110044
# 0      [CLS]        eating  0.094220
# 19        to         lunch  0.055442
# 20        go        eating  0.034889
# 16   goodbye        eating  0.033007
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 24     eating         lunch  0.212768
# 25      lunch        eating  0.212768
# 13    sisters        eating  0.129051
# 22      after        eating  0.117822
# 21   packages        eating  0.064063
# 23       just        eating  0.051731
# 0       [CLS]        eating  0.044495
# 4   embracing        eating  0.038352
# 19         to         lunch  0.034915
# 16    goodbye        eating  0.029751
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 25      lunch        eating  0.303103
# 24     eating         lunch  0.303103
# 13    sisters        eating  0.243091
# 22      after        eating  0.168445
# 21   packages        eating  0.118461
# 4   embracing        eating  0.114649
# 0       [CLS]       sisters  0.096857
# 19         to        eating  0.073888
# 23       just        eating  0.073545
# 15    hugging        eating  0.058351
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 25      lunch        eating  0.176982
# 24     eating         lunch  0.176981
# 13    sisters        eating  0.152941
# 22      after        eating  0.104093
# 21   packages        eating  0.096452
# 0       [CLS]        eating  0.062511
# 23       just        eating  0.057022
# 16    goodbye        eating  0.045329
# 4   embracing        eating  0.039964
# 8          go         lunch  0.037563
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 24     eating         lunch  0.166851
# 25      lunch        eating  0.166850
# 13    sisters        eating  0.124378
# 22      after        eating  0.113545
# 21   packages        eating  0.094411
# 23       just        eating  0.063566
# 0       [CLS]        eating  0.045048
# 16    goodbye        eating  0.038196
# 4   embracing        eating  0.030748
# 15    hugging        eating  0.020998
# ------------------------------

# %% [markdown]
# ## Max

# %%
for k in batch_list:
    batch = str(k)
    sent = str(sentence_num)
    batch_0_x_sent_0 = torch.load('tensor/batch_{}_x_sent_{}.pt'.format(batch, sent)).squeeze(0)
    batch_0_hess_0 = torch.load('tensor/batch_{}_hess_{}.pt'.format(batch, sent)).squeeze(0)
    # print(batch_0_x_sent_0)

    ori_sentence = tokenizer.convert_ids_to_tokens(batch_0_x_sent_0)
    print(tokenizer.convert_ids_to_tokens(batch_0_x_sent_0))
    temp = dict([i, ori_sentence[i]] for i in range(len(ori_sentence)))

    # print(torch.abs(batch_0_hess_0))
    abs_hess = torch.abs(batch_0_hess_0)
    # no_diag_hess = abs_hess - abs_hess.max() * torch.eye(abs_hess.shape[0], device='cuda:0')

    # abs_hess.split(128)
    # conv = torch.nn.Conv2d(1, 1, (128, 128), padding=0, stride=128).to('cuda:0')(abs_hess.unsqueeze(0).unsqueeze(0))
    avg_hess = torch.nn.AvgPool2d(128, stride=128).to('cuda:0')(abs_hess.unsqueeze(0))[0] - torch.eye(40, device='cuda:0') * 10
    max_hess = torch.nn.MaxPool2d(128, stride=128).to('cuda:0')(abs_hess.unsqueeze(0))[0] - torch.eye(40, device='cuda:0') * 10

    values, indices = max_hess.max(1)
    pairs = [[i, int(indices[i]), float(values[i])] for i in range(indices.shape[0]) if float(values[i]) != 0]

    df = pd.DataFrame(pairs)
    df.columns = ['word', 'most relavent', 'score']
    df = df.replace(temp)
    df.sort_values('score', ascending=False, inplace=True)
    print(df.head(topk))

    print("-" * 30 + '\n')
# Out:
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 27      [SEP]         [SEP]  0.561189
# 11      [SEP]         [SEP]  0.561189
# 0       [CLS]         [SEP]  0.497816
# 21   packages      packages  0.199171
# 9    packages      packages  0.199171
# 2       women         [SEP]  0.170174
# 13    sisters         [SEP]  0.159542
# 10          .         [SEP]  0.124365
# 4   embracing         [SEP]  0.124075
# 26          .         [SEP]  0.115160
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 21  packages      packages  0.562318
# 9   packages      packages  0.562318
# 8         go            go  0.394975
# 20        go            go  0.394975
# 24    eating            to  0.182297
# 19        to        eating  0.182297
# 25     lunch        eating  0.178500
# 27     [SEP]        eating  0.177777
# 0      [CLS]        eating  0.143524
# 22     after            to  0.123214
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 21  packages      packages  0.247357
# 9   packages      packages  0.247357
# 8         go            go  0.192579
# 20        go            go  0.192579
# 25     lunch        eating  0.177154
# 24    eating         lunch  0.177154
# 22     after            to  0.161719
# 19        to         after  0.161719
# 0      [CLS]        eating  0.095075
# 23      just         after  0.070906
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch        eating  0.848008
# 24    eating         lunch  0.848008
# 22     after        eating  0.440922
# 20        go            go  0.310622
# 8         go            go  0.310622
# 19        to        eating  0.299043
# 0      [CLS]        eating  0.286968
# 9   packages        eating  0.170760
# 23      just         after  0.166009
# 21  packages      packages  0.153212
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#        word most relavent     score
# 25    lunch        eating  0.914315
# 24   eating         lunch  0.914315
# 22    after        eating  0.912405
# 19       to        eating  0.544790
# 0     [CLS]        eating  0.456856
# 27    [SEP]        eating  0.330127
# 23     just        eating  0.230520
# 2     women        eating  0.229750
# 13  sisters            to  0.215821
# 18  holding        eating  0.214563
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch        eating  0.894401
# 24    eating         lunch  0.894401
# 22     after        eating  0.589855
# 23      just         after  0.435472
# 2      women        eating  0.226559
# 0      [CLS]        eating  0.206532
# 13   sisters         [CLS]  0.205490
# 27     [SEP]        eating  0.139645
# 21  packages        eating  0.105143
# 20        go        eating  0.103221
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch         after  0.974866
# 22     after         lunch  0.974866
# 24    eating         after  0.966098
# 13   sisters        eating  0.552054
# 0      [CLS]       sisters  0.493898
# 2      women        eating  0.443568
# 20        go        eating  0.266300
# 23      just         after  0.186768
# 19        to         after  0.164843
# 21  packages        eating  0.157467
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch        eating  2.978237
# 24    eating         lunch  2.978237
# 8         go            go  1.487515
# 20        go            go  1.487515
# 9   packages      packages  1.187142
# 21  packages      packages  1.187142
# 23      just        eating  0.970829
# 22     after          just  0.723180
# 13   sisters        eating  0.527677
# 7         to        eating  0.400122
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating         lunch  1.553198
# 25     lunch        eating  1.553198
# 13   sisters        eating  0.756236
# 22     after         lunch  0.542156
# 23      just        eating  0.494318
# 7         to        eating  0.384816
# 0      [CLS]       sisters  0.367874
# 19        to         lunch  0.267648
# 21  packages        eating  0.238457
# 5      while        eating  0.227209
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch        eating  1.463998
# 24    eating         lunch  1.463998
# 22     after        eating  0.756445
# 13   sisters        eating  0.538660
# 23      just        eating  0.296789
# 27     [SEP]        eating  0.266249
# 0      [CLS]        eating  0.228141
# 7         to        eating  0.213732
# 2      women        eating  0.212291
# 21  packages        eating  0.209088
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 25     lunch        eating  0.962837
# 24    eating         lunch  0.962837
# 22     after        eating  0.784678
# 9   packages        eating  0.331735
# 23      just         after  0.300566
# 13   sisters        eating  0.300465
# 21  packages        eating  0.227460
# 7         to        eating  0.214569
# 0      [CLS]        eating  0.172654
# 5      while        eating  0.168860
# ------------------------------
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating         after  1.734849
# 22     after        eating  1.734849
# 25     lunch        eating  1.371277
# 13   sisters        eating  0.905416
# 21  packages        eating  0.447745
# 27     [SEP]        eating  0.422704
# 0      [CLS]       sisters  0.362494
# 23      just        eating  0.334188
# 16   goodbye        eating  0.199480
# 19        to        eating  0.193092
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 24     eating       sisters  2.297487
# 13    sisters        eating  2.297487
# 25      lunch        eating  2.201710
# 22      after        eating  1.032289
# 4   embracing        eating  0.386009
# 9    packages        eating  0.374456
# 21   packages        eating  0.336439
# 7          to        eating  0.330939
# 11      [SEP]        eating  0.311655
# 2       women        eating  0.300949
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 24    eating       sisters  1.006577
# 13   sisters        eating  1.006577
# 25     lunch        eating  0.853266
# 0      [CLS]       sisters  0.643398
# 22     after        eating  0.464107
# 21  packages        eating  0.358100
# 23      just        eating  0.346342
# 16   goodbye        eating  0.209017
# 20        go        eating  0.206178
# 9   packages        eating  0.200357
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#         word most relavent     score
# 13   sisters        eating  1.064729
# 24    eating       sisters  1.064729
# 22     after        eating  0.779680
# 25     lunch        eating  0.762154
# 21  packages        eating  0.440680
# 23      just        eating  0.279914
# 0      [CLS]       sisters  0.269888
# 17     while        eating  0.269066
# 16   goodbye        eating  0.244805
# 27     [SEP]        eating  0.187440
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 24     eating       sisters  1.508877
# 13    sisters        eating  1.508877
# 25      lunch        eating  1.216731
# 22      after        eating  1.127992
# 16    goodbye        eating  0.398880
# 21   packages        eating  0.397416
# 0       [CLS]       sisters  0.335833
# 23       just        eating  0.315512
# 15    hugging        eating  0.281661
# 4   embracing        eating  0.175254
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 25      lunch        eating  3.439790
# 24     eating         lunch  3.439790
# 22      after         lunch  3.100429
# 13    sisters         lunch  1.990922
# 21   packages        eating  1.168820
# 23       just         lunch  0.729626
# 0       [CLS]       sisters  0.684584
# 4   embracing        eating  0.397857
# 19         to         lunch  0.394148
# 15    hugging        eating  0.337203
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 24     eating         lunch  2.304117
# 25      lunch        eating  2.304117
# 13    sisters        eating  1.420820
# 22      after        eating  0.941772
# 21   packages        eating  0.533745
# 23       just        eating  0.414172
# 4   embracing        eating  0.399838
# 0       [CLS]       sisters  0.342372
# 16    goodbye        eating  0.316983
# 19         to        eating  0.308190
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 25      lunch        eating  2.748668
# 24     eating         lunch  2.748668
# 13    sisters        eating  2.536877
# 4   embracing        eating  1.404371
# 22      after        eating  1.198687
# 21   packages        eating  0.951071
# 0       [CLS]       sisters  0.824937
# 19         to        eating  0.682856
# 23       just        eating  0.655705
# 15    hugging        eating  0.606543
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 25      lunch        eating  1.826137
# 24     eating         lunch  1.826137
# 13    sisters        eating  1.768166
# 22      after        eating  0.913942
# 8          go         lunch  0.609475
# 21   packages        eating  0.599674
# 0       [CLS]       sisters  0.504877
# 16    goodbye        eating  0.463680
# 4   embracing        eating  0.437960
# 23       just        eating  0.396049
# ------------------------------
#
# ['[CLS]', 'two', 'women', 'are', 'embracing', 'while', 'holding', 'to', 'go', 'packages', '.', '[SEP]', 'the', 'sisters', 'are', 'hugging', 'goodbye', 'while', 'holding', 'to', 'go', 'packages', 'after', 'just', 'eating', 'lunch', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]', '[PAD]']
#          word most relavent     score
# 24     eating       sisters  1.545403
# 13    sisters        eating  1.545403
# 25      lunch        eating  1.222044
# 22      after        eating  0.841630
# 21   packages        eating  0.683149
# 23       just        eating  0.547811
# 16    goodbye        eating  0.400313
# 4   embracing        eating  0.371251
# 0       [CLS]        eating  0.305453
# 9    packages        eating  0.236040
# ------------------------------
