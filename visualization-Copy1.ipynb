# %% [markdown]
# # Visualizing results from BERT-tiny

# %%
import torch
from transformers import *
import pandas as pd
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def visualize(topk, sentence_num, batch_list, mode='avg'):
    
    for k in batch_list:
        
        batch = str(k)
        sent = str(sentence_num)
        batch_0_x_sent_0 = torch.load('tensor/batch_{}_x_sent_{}.pt'.format(batch, sent)).squeeze(0)
        batch_0_hess_0 = torch.load('tensor/batch_{}_hess_{}.pt'.format(batch, sent)).squeeze(0)
        cause_mask = torch.load('tensor/batch_{}_cause_mask_{}.pt'.format(batch, sent))
        # print(batch_0_x_sent_0)

        ori_sentence = tokenizer.convert_ids_to_tokens(batch_0_x_sent_0)
        print(tokenizer.convert_ids_to_tokens(batch_0_x_sent_0))
        print('\n cause mask: ', [ori_sentence[i] for i in range(len(ori_sentence)) if cause_mask[0][i] != 0], '\n')
        
        temp = dict([i, ori_sentence[i]] for i in range(len(ori_sentence)))

        # print(torch.abs(batch_0_hess_0))
        abs_hess = torch.abs(batch_0_hess_0)
        # no_diag_hess = abs_hess - abs_hess.max() * torch.eye(abs_hess.shape[0], device='cuda:0')

        # abs_hess.split(128)
        # conv = torch.nn.Conv2d(1, 1, (128, 128), padding=0, stride=128).to('cuda:0')(abs_hess.unsqueeze(0).unsqueeze(0))
        avg_hess = torch.nn.AvgPool2d(128, stride=128).to('cuda:0')(abs_hess.unsqueeze(0))[0] - torch.eye(40, device='cuda:0') * 10
        max_hess = torch.nn.MaxPool2d(128, stride=128).to('cuda:0')(abs_hess.unsqueeze(0))[0] - torch.eye(40, device='cuda:0') * 10
        if mode == 'avg':
            values, indices = avg_hess.max(1)
        else:
            values, indices = max_hess.max(1)
        pairs = [[i, int(indices[i]), float(values[i])] for i in range(indices.shape[0]) if float(values[i]) != 0]

        df = pd.DataFrame(pairs)
        df.columns = ['word', 'most relavent', 'score']
        df = df.replace(temp)
        df.sort_values('score', ascending=False, inplace=True)
        print(df.head(topk))

        print("-" * 30 + '\n')

# %% [markdown]
# # Params for visualization

# %%
topk = 10
sentence_num = 5 # select one from 0 to 15
batch_list = [0, 62, 124, 186, 248, 310, 375, 437, 499, 561, 623, 688, 750, 812, 874, 936, 1001, 1063, 1125, 1187, 1249]

# %% [markdown]
# ## Average

# %%
visualize(topk, sentence_num, batch_list, mode='avg')
# Out:
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 39     [SEP]         [SEP]  0.025032
# 30     [SEP]         [SEP]  0.025031
# 0      [CLS]         [SEP]  0.017122
# 38         .         [SEP]  0.008138
# 32      kids         [SEP]  0.008067
# 35      walk         [SEP]  0.007766
# 37    school         [SEP]  0.007385
# 29     their         [SEP]  0.007075
# 19       are         [SEP]  0.006904
# 26  bathroom         [SEP]  0.006482
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 29     their      bathroom  0.033214
# 26  bathroom         their  0.033214
# 0      [CLS]      bathroom  0.027550
# 30     [SEP]      bathroom  0.024239
# 34   jackets       jerseys  0.021284
# 6    jerseys       jackets  0.021284
# 28   washing      bathroom  0.020694
# 36        to      bathroom  0.017670
# 32      kids      bathroom  0.013806
# 37    school      bathroom  0.013363
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 26  bathroom       washing  0.131543
# 28   washing      bathroom  0.131543
# 32      kids       washing  0.081920
# 29     their       washing  0.054744
# 9       with       washing  0.044637
# 3   children       washing  0.040403
# 0      [CLS]       washing  0.038814
# 36        to       washing  0.037163
# 27       and       washing  0.036904
# 23     steps       washing  0.036048
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 36        to          kids  0.047590
# 32      kids            to  0.047590
# 29     their            to  0.039809
# 28   washing          kids  0.033288
# 35      walk            to  0.031061
# 26  bathroom       washing  0.020849
# 0      [CLS]      bathroom  0.016664
# 31       two          kids  0.012704
# 6    jerseys       jackets  0.011798
# 34   jackets       jerseys  0.011798
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 28   washing            to  0.103311
# 36        to       washing  0.103311
# 29     their            to  0.050903
# 32      kids            to  0.050679
# 26  bathroom       washing  0.048217
# 31       two            to  0.039289
# 0      [CLS]            to  0.034156
# 3   children          kids  0.032586
# 35      walk       washing  0.020472
# 37    school            to  0.015118
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 36        to         their  0.075225
# 29     their            to  0.075225
# 28   washing            to  0.056492
# 32      kids       washing  0.036864
# 37    school            to  0.031027
# 26  bathroom       washing  0.025574
# 35      walk            to  0.018570
# 3   children          kids  0.017690
# 0      [CLS]            to  0.014069
# 22    wooden            to  0.010672
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 28   washing            to  0.064290
# 36        to       washing  0.064290
# 35      walk            to  0.064177
# 26  bathroom       washing  0.064160
# 37    school            to  0.060116
# 29     their            to  0.057656
# 0      [CLS]            to  0.050649
# 32      kids       washing  0.044614
# 34   jackets       washing  0.042802
# 3   children          walk  0.032112
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 35      walk            to  0.073879
# 36        to          walk  0.073879
# 28   washing       jackets  0.057304
# 34   jackets       washing  0.057304
# 29     their            to  0.048728
# 37    school            to  0.044889
# 26  bathroom       washing  0.044438
# 32      kids       washing  0.039345
# 30     [SEP]       washing  0.035265
# 0      [CLS]            to  0.033433
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 28   washing            to  0.057537
# 36        to       washing  0.057537
# 26  bathroom       washing  0.051015
# 37    school            to  0.038035
# 34   jackets            to  0.031694
# 35      walk            to  0.026070
# 0      [CLS]            to  0.023093
# 32      kids       washing  0.020373
# 29     their            to  0.012018
# 6    jerseys       jackets  0.010963
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 28   washing            to  0.077618
# 36        to       washing  0.077618
# 26  bathroom       washing  0.065143
# 35      walk            to  0.059721
# 34   jackets       washing  0.058631
# 32      kids       washing  0.047709
# 37    school            to  0.047619
# 29     their       washing  0.035847
# 25         a       washing  0.025964
# 31       two       washing  0.025106
# ------------------------------
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 36        to       washing  0.124716
# 28   washing            to  0.124716
# 34   jackets            to  0.082201
# 32      kids       washing  0.063362
# 26  bathroom       washing  0.061207
# 35      walk       washing  0.050184
# 29     their            to  0.042939
# 37    school            to  0.042271
# 25         a       washing  0.027991
# 31       two       washing  0.025272
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 28   washing            to  0.112382
# 36        to       washing  0.112382
# 34   jackets       washing  0.112351
# 32      kids       washing  0.084005
# 26  bathroom       washing  0.069112
# 29     their       washing  0.062057
# 37    school            to  0.051800
# 25         a       washing  0.041765
# 6    jerseys       jackets  0.033010
# 0      [CLS]       washing  0.028801
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 28   washing       jackets  0.057934
# 34   jackets       washing  0.057934
# 6    jerseys       jackets  0.050405
# 36        to       jackets  0.044084
# 35      walk            to  0.039675
# 32      kids       washing  0.038789
# 37    school            to  0.029831
# 31       two          walk  0.020874
# 26  bathroom       washing  0.018619
# 25         a       washing  0.016640
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 28   washing       jackets  0.117377
# 34   jackets       washing  0.117376
# 36        to       jackets  0.094315
# 32      kids       washing  0.080083
# 37    school       jackets  0.061849
# 6    jerseys       jackets  0.060616
# 26  bathroom       washing  0.057058
# 0      [CLS]       washing  0.041023
# 31       two       washing  0.030795
# 35      walk       washing  0.026679
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 34   jackets       washing  0.209931
# 28   washing       jackets  0.209931
# 32      kids       washing  0.136431
# 36        to       washing  0.105419
# 37    school       washing  0.075557
# 26  bathroom       washing  0.072180
# 0      [CLS]       washing  0.051162
# 27       and       washing  0.048875
# 25         a       washing  0.047776
# 22    wooden       washing  0.041329
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 34   jackets       washing  0.218963
# 28   washing       jackets  0.218962
# 25         a       washing  0.102098
# 36        to       washing  0.077309
# 32      kids       washing  0.075298
# 26  bathroom       washing  0.067270
# 23     steps       washing  0.051288
# 22    wooden       washing  0.046073
# 37    school            to  0.041114
# 31       two       washing  0.039323
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 34   jackets       washing  0.341623
# 28   washing       jackets  0.341622
# 25         a       washing  0.230288
# 36        to       washing  0.225619
# 32      kids       washing  0.194278
# 26  bathroom       washing  0.163910
# 27       and       washing  0.129240
# 22    wooden       washing  0.096180
# 31       two       washing  0.090362
# 29     their       washing  0.077011
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 26  bathroom       washing  0.144542
# 28   washing      bathroom  0.144542
# 32      kids       washing  0.129450
# 27       and       washing  0.128586
# 36        to       washing  0.122191
# 34   jackets       washing  0.107426
# 37    school            to  0.076827
# 6    jerseys       jackets  0.072361
# 25         a       washing  0.065681
# 0      [CLS]       washing  0.055029
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 28   washing       jackets  0.212675
# 34   jackets       washing  0.212675
# 6    jerseys       jackets  0.179179
# 32      kids       washing  0.166110
# 36        to       washing  0.138268
# 27       and       washing  0.135421
# 26  bathroom       washing  0.114995
# 37    school       washing  0.110739
# 0      [CLS]       washing  0.093615
# 22    wooden       washing  0.073804
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 28   washing       jackets  0.169895
# 34   jackets       washing  0.169895
# 32      kids       washing  0.128399
# 26  bathroom       washing  0.128081
# 36        to       washing  0.108136
# 37    school       washing  0.102923
# 27       and       washing  0.091282
# 0      [CLS]       washing  0.060665
# 22    wooden       washing  0.053928
# 35      walk       washing  0.040091
# ------------------------------
#
# ['[CLS]', 'two', 'young', 'children', 'in', 'blue', 'jerseys', ',', 'one', 'with', 'the', 'number', '9', 'and', 'one', 'with', 'the', 'number', '2', 'are', 'standing', 'on', 'wooden', 'steps', 'in', 'a', 'bathroom', 'and', 'washing', 'their', '[SEP]', 'two', 'kids', 'in', 'jackets', 'walk', 'to', 'school', '.', '[SEP]']
#
#  cause mask:  ['blue', 'in', 'a', 'jackets', 'walk', 'to', 'school']
#
#         word most relavent     score
# 28   washing       jackets  0.254835
# 34   jackets       washing  0.254834
# 32      kids       washing  0.127622
# 26  bathroom       washing  0.120544
# 25         a       washing  0.104365
# 36        to       washing  0.083774
# 37    school       washing  0.072662
# 22    wooden       washing  0.062073
# 31       two       washing  0.061231
# 29     their       washing  0.050915
# ------------------------------

# %% [markdown]
# ## Max

# %%
visualize(topk, sentence_num, batch_list, mode='max')
# Out:
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 20       [SEP]         [SEP]  0.522676
# 39       [SEP]         [SEP]  0.522676
# 13       event         event  0.458439
# 33       event         event  0.458439
# 0        [CLS]         event  0.412748
# 28    customer         [CLS]  0.303048
# 23     selling         [CLS]  0.299778
# 25       ##uts         ##uts  0.250136
# 5        ##uts         ##uts  0.250136
# 32  exhibition         event  0.247122
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 8     customer      customer  2.159835
# 28    customer      customer  2.159835
# 32  exhibition    exhibition  0.897711
# 12  exhibition    exhibition  0.897711
# 0        [CLS]      customer  0.644162
# 30           a      customer  0.451184
# 26          to      customer  0.431918
# 13       event      customer  0.405314
# 33       event      customer  0.369544
# 35      people      customer  0.268688
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 12  exhibition    exhibition  1.218708
# 32  exhibition    exhibition  1.218708
# 8     customer      customer  1.150113
# 28    customer      customer  1.150113
# 26          to    exhibition  0.388271
# 0        [CLS]    exhibition  0.312086
# 19     angeles      customer  0.284499
# 5        ##uts         ##uts  0.193565
# 25       ##uts         ##uts  0.193565
# 29      during    exhibition  0.147482
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 12  exhibition          wait  0.276033
# 36        wait    exhibition  0.276033
# 35      people          wait  0.208942
# 26          to        during  0.179708
# 29      during            to  0.179708
# 8     customer          wait  0.147357
# 4          don          wait  0.112526
# 32  exhibition    exhibition  0.105067
# 0        [CLS]          wait  0.097836
# 19     angeles    exhibition  0.090173
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 36        wait    exhibition  0.980557
# 12  exhibition          wait  0.980557
# 35      people          wait  0.726270
# 26          to          wait  0.566242
# 32  exhibition    exhibition  0.386776
# 8     customer          wait  0.383227
# 4          don          wait  0.358698
# 29      during            to  0.323131
# 9       during          wait  0.256731
# 34       while        people  0.218326
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 12  exhibition          wait  2.163618
# 36        wait    exhibition  2.163618
# 35      people          wait  1.916104
# 0        [CLS]          wait  0.791255
# 8     customer          wait  0.724380
# 32  exhibition          wait  0.710903
# 29      during          wait  0.588102
# 4          don          wait  0.569337
# 26          to          wait  0.546532
# 31       world          wait  0.544030
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 36        wait        people  1.594391
# 35      people          wait  1.594391
# 38        line          wait  1.411736
# 12  exhibition          line  1.178469
# 32  exhibition    exhibition  0.961667
# 31       world        people  0.843044
# 8     customer          wait  0.651642
# 0        [CLS]        people  0.559715
# 4          don          wait  0.523944
# 28    customer        people  0.451609
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 38        line          wait  1.829595
# 36        wait          line  1.829595
# 12  exhibition    exhibition  1.669771
# 32  exhibition    exhibition  1.669771
# 8     customer          wait  1.487924
# 35      people          wait  1.415385
# 19     angeles    exhibition  1.005482
# 31       world          wait  0.957128
# 33       event          wait  0.553832
# 4          don          wait  0.546827
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 8     customer          wait  1.304468
# 36        wait      customer  1.304468
# 35      people          wait  0.798792
# 12  exhibition          wait  0.713765
# 19     angeles    exhibition  0.696980
# 32  exhibition    exhibition  0.623009
# 31       world          wait  0.594111
# 26          to          wait  0.450835
# 3      selling          wait  0.433844
# 4          don          wait  0.311739
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 12  exhibition          line  2.882161
# 38        line    exhibition  2.882161
# 35      people          wait  2.538291
# 36        wait        people  2.538291
# 8     customer          wait  1.461439
# 32  exhibition          line  1.334219
# 31       world          wait  1.034849
# 24         don          wait  0.579651
# 26          to          wait  0.569056
# 4          don          wait  0.485428
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 38        line          wait  1.774301
# 36        wait          line  1.774301
# 35      people          wait  1.510934
# 8     customer          wait  0.840536
# 12  exhibition          wait  0.811013
# 31       world          wait  0.531724
# 32  exhibition    exhibition  0.516491
# 34       while          wait  0.377743
# 2          man          wait  0.373296
# 33       event          wait  0.337671
# ------------------------------
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 35      people          wait  2.892927
# 36        wait        people  2.892927
# 12  exhibition    exhibition  2.713221
# 32  exhibition    exhibition  2.713221
# 38        line        people  1.384827
# 8     customer          wait  1.331163
# 2          man        people  1.041624
# 31       world          wait  0.857795
# 26          to          wait  0.576123
# 33       event        people  0.537918
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 36        wait        people  1.911478
# 35      people          wait  1.911478
# 38        line        people  1.570935
# 2          man        people  1.398025
# 32  exhibition    exhibition  1.389365
# 12  exhibition    exhibition  1.389365
# 8     customer          wait  0.781342
# 31       world          wait  0.604035
# 33       event        people  0.448896
# 17        city        people  0.401080
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 36        wait        people  1.800303
# 35      people          wait  1.800303
# 12  exhibition    exhibition  1.676307
# 32  exhibition    exhibition  1.676307
# 2          man        people  1.215021
# 8     customer          wait  1.093693
# 38        line        people  0.962591
# 31       world          wait  0.961861
# 11       world        people  0.509975
# 33       event        people  0.486504
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 36        wait    exhibition  2.439846
# 12  exhibition          wait  2.439846
# 32  exhibition    exhibition  2.249497
# 35      people          wait  1.374707
# 38        line          wait  1.295465
# 8     customer          wait  0.945714
# 2          man        people  0.718706
# 26          to          wait  0.694750
# 31       world    exhibition  0.694118
# 33       event        people  0.480504
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 35      people          wait  2.878548
# 36        wait        people  2.878548
# 31       world          wait  1.643496
# 12  exhibition          wait  1.626995
# 38        line          wait  1.359555
# 8     customer          wait  1.282207
# 32  exhibition    exhibition  1.104639
# 2          man        people  0.837193
# 11       world        people  0.554403
# 30           a          wait  0.528766
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 35      people          wait  2.800219
# 36        wait        people  2.800219
# 31       world          wait  1.712291
# 12  exhibition          wait  1.417427
# 38        line          wait  1.224440
# 32  exhibition    exhibition  1.139156
# 8     customer          wait  1.134888
# 0        [CLS]          wait  1.011960
# 30           a          wait  0.671395
# 26          to          wait  0.598226
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 35      people          wait  2.195094
# 36        wait        people  2.195094
# 31       world          wait  1.531097
# 38        line          wait  1.474048
# 12  exhibition          wait  1.236098
# 26          to          wait  0.922483
# 8     customer          wait  0.727247
# 32  exhibition    exhibition  0.721084
# 0        [CLS]          wait  0.558030
# 24         don          wait  0.546681
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 35      people          wait  2.915475
# 36        wait        people  2.915475
# 31       world          wait  1.721053
# 8     customer          wait  1.621637
# 12  exhibition          wait  1.346984
# 38        line          wait  1.105516
# 26          to          wait  1.079183
# 32  exhibition    exhibition  1.073322
# 13       event          line  0.741411
# 25       ##uts          wait  0.715450
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent     score
# 38        line          wait  2.013594
# 36        wait          line  2.013594
# 35      people          wait  1.990057
# 13       event          line  1.164198
# 12  exhibition          wait  1.026708
# 8     customer          wait  1.015864
# 32  exhibition    exhibition  0.931566
# 31       world          wait  0.749857
# 9       during          line  0.511997
# 5        ##uts          line  0.474483
# ------------------------------
#
# ['[CLS]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'held', 'in', 'the', 'city', 'of', 'angeles', '[SEP]', 'a', 'man', 'selling', 'don', '##uts', 'to', 'a', 'customer', 'during', 'a', 'world', 'exhibition', 'event', 'while', 'people', 'wait', 'in', 'line', '[SEP]']
#
#  cause mask:  ['people', 'wait', 'in', 'line']
#
#           word most relavent      score
# 38        line          line  14.191631
# 36        wait          line   6.389989
# 13       event          line   4.226126
# 35      people          wait   3.571645
# 8     customer          line   2.231858
# 17        city          line   1.677328
# 31       world          wait   1.451663
# 0        [CLS]          line   1.384784
# 12  exhibition          line   1.312883
# 9       during          line   1.221059
# ------------------------------
